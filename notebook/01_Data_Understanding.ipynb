# %% [markdown]
# # Retail Intelligence Business Analytics
#
# ## Notebook 1: Data Understanding
#
# ### Objective
#
# The objective of this notebook is to explore the Global Superstore dataset, understand its structure, examine key attributes, and perform an initial assessment before performing data quality assessment, cleaning, feature engineering, and business analysis.

# %%
#Importing Libraries:

import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# %%
df = pd.read_excel(
    "../data/raw/Global Superstore Data.xlsx",
    sheet_name="Orders"
)

# %% [markdown]
# ## Step 1: Preview the Dataset
#
# Display the first few records of the dataset to verify that it has been loaded correctly and to gain an initial understanding of its structure and contents.

# %%
df.head()
# Out:
#    Row ID                Order ID Order Date  Ship Date       Ship Mode  \
# 0   24599  IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 1   29465  ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
# 2   24598  IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 3   24597  IN-2017-CA120551-42816 2017-03-22 2017-03-29  Standard Class
# 4   29464  ID-2015-BD116051-42248 2015-09-01 2015-09-04    Second Class
#
#   Customer ID    Customer Name      Segment  Postal Code   City  State  \
# 0   CA-120551  Cathy Armstrong  Home Office          NaN  Herat  Hirat
# 1   BD-116051     Brian Dahlen     Consumer          NaN  Herat  Hirat
# 2   CA-120551  Cathy Armstrong  Home Office          NaN  Herat  Hirat
# 3   CA-120551  Cathy Armstrong  Home Office          NaN  Herat  Hirat
# 4   BD-116051     Brian Dahlen     Consumer          NaN  Herat  Hirat
#
#        Country         Region        Market   Product ID  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Postal Code',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Market',
#  'Product ID',
#  'Product Name',
#  'Sub-Category',
#  'Category',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority']

# %% [markdown]
# ## Step 2: Inspect Dataset Structure
#
# The `info()` method provides a summary of the dataset, including:
#
# - Number of rows and columns
# - Data types
# - Non-null values
# - Memory usage
#
# This helps identify missing values and ensures that each column has the expected data type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Product Name    51290 non-null  object
# ...

# %%
df.sample(5, random_state=42)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 49728   39143  CA-2015-JK15205140-42274 2015-09-27 2015-10-02  Standard Class
# 45547   36842  CA-2017-MG17890140-43001 2017-09-23 2017-09-27  Standard Class
# 15664   11413   ES-2017-PT1909048-42954 2017-08-07 2017-08-10     First Class
# 40561   35001  CA-2015-DH13075140-42168 2015-06-13 2015-06-19  Standard Class
# 49426   39371  CA-2017-JM15250140-42737 2017-01-02 2017-01-06  Standard Class
#
#         Customer ID     Customer Name      Segment  Postal Code  \
# 49728  JK-152051408      Jamie Kunitz     Consumer      22204.0
# 45547  MG-178901406  Michael Granlund  Home Office       3301.0
# 15664    PT-1909048     Pete Takahito     Consumer          NaN
# 40561  DH-130751408     Dave Hallsten    Corporate      35601.0
# 49426  JM-152501402      Janet Martin     Consumer      77340.0
#
#                 City          State        Country          Region  Market  \
# ...

# %% [markdown]
# ## Step 3: Summary Statistics
#
# Generate descriptive statistics for numerical columns to understand the distribution of the data and identify any unusual values.

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2016-05-11 11:52:18.436342272
# min        1.00000            2014-01-01 00:00:00
# 25%    12823.25000            2015-06-19 00:00:00
# 50%    25645.50000            2016-07-08 00:00:00
# 75%    38467.75000            2017-05-22 00:00:00
# max    51290.00000            2017-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2016-05-15 11:09:41.306297344  55190.379428    246.490581
# min              2014-01-03 00:00:00   1040.000000      0.444000
# 25%              2015-06-23 00:00:00  23223.000000     30.758625
# 50%              2016-07-12 00:00:00  56430.500000     85.053000
# 75%              2017-05-26 00:00:00  90008.000000    251.053200
# ...

# %% [markdown]
# ## Step 4: Explore Categorical Columns
#
# Display summary statistics for categorical variables to understand the variety of values present in the dataset.

# %%
df.describe(include="object")
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2017-SV20365140-42999  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1106            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID Product Name Sub-Category  \
# count            51290         51290        51290        51290        51290
# unique              23             5         3788         3788           17
# ...

# %% [markdown]
# ## Conclusion
#
# The initial exploration confirms that the Global Superstore dataset has been loaded successfully and contains sufficient information for comprehensive business analysis.
#
# Key observations:
#
# - The dataset contains 51,290 records and 24 original features.
# - Both numerical and categorical variables are present.
# - Order and shipping dates have been imported correctly.
# - Sales, Profit, Quantity, and Discount are available for performance analysis.
# - Customer, Product, and Geographic information will support segmentation and regional analysis.
#
# The next notebook focuses on assessing data quality by identifying missing values, duplicates, inconsistent records, and potential data issues before feature engineering.
